# %% [markdown]
# # 1. Code của chương trình. Khi sử dụng code thì "Run All" và thao tác ở task "Chạy chương trình"

# %%
import numpy as np
import pandas as pd

# %%
def doc_input(ten_file):
    # tra ve gia tri cua x va y tu file input.xlsx
    # doc file input.xlsx su dung pandas
    data = pd.read_excel(ten_file)
    
    # doc du lieu cua x va y
    x = data.iloc[:, 0]  # Assuming x is in the first column
    y = data.iloc[:, 1]  # Assuming y is in the second column
    
    # xu ly du lieu cua x va y
    x = np.array(x, dtype=float)
    if y.isnull().all():  # Check if y is empty or contains NaNs
        y = f(x)  # Assuming f(x) is a function defined elsewhere
        y = np.array(y, dtype=float)
    else:
        y = np.array(y, dtype=float)
    
    return x, y

def hoocnerChia(a, value):
    b = [a[0]]
    for i in range(1, len(a)):
        b.append(a[i] + b[i - 1] * value)
    return b
    
def hoocne_product(x):
    a = []
    Li = [np.array([1])]
    a.append(np.array([1, 0]))
    for i in x:
        b = a[-1]
        c = []
        c.append(1)
        for j in range(len(b) - 1):
            c.append(b[j + 1]- b[j] * i)
        c.append(0)
        a.append(np.array(c))
        Li.append(np.delete(a[-1], -1))
    return Li

def hoocne_quatient(a, x):
    y = []
    y.append(a[0])
    for i in range(len(a) - 1):
        y.append(y[i] * x + a[i + 1])
    b = np.array(y[:-1])
    b_0 = np.array(y[-1])
    return b, b_0

def nsNewton_bat_ki(x, y):
    P = []
    Z = []
    Li = hoocne_product(x)
    for i in range(x.shape[0]):
        z = [y[i]]
        for j in range(i):
            z.append((z[j] - Z[i - 1][j]) / (x[i] - x[i - j - 1]))
        Z.append(np.array(z))
        Fi = Z[i][i]
        if i == 0:
            P.append(np.array(Fi * Li[i]))
        else:
            P.append(np.concatenate((np.array([0]), P[i - 1])) + Fi * Li[i])
    return P[-1].tolist()

# %% [markdown]
# # Chạy chương trình

# %% [markdown]
# ## 1. Nhập dữ liệu

# %% [markdown]
# Demo

# %%
x, y = doc_input("input.xlsx")
print("Mốc nội suy x: {0}".format(x))
print("Mốc nội suy y: {0}\n".format(y))
a = nsNewton_bat_ki(x, y)
print("Đa thức nội suy là: \nBậc đa thức nội suy: {0}\n".format(len(a) - 1))
for i in range(len(a)):
    print("{0} x^{1}".format(a[i], len(a)-1-i))
# Out:
# Mốc nội suy x: [1.57 1.59 1.62 1.64 1.67 1.71 1.74]
# Mốc nội suy y: [2.46 2.59 2.77 2.9  3.09 3.34 3.53]
#
# Bảng tỷ sai phân:
# [array([2.46]), array([2.59, 6.5 ]), array([  2.77,   6.  , -10.  ]), array([  2.9       ,   6.5       ,  10.        , 285.71428571]), array([ 3.09000000e+00,  6.33333333e+00, -3.33333333e+00, -1.66666667e+02,
#        -4.52380952e+03]), array([ 3.34000000e+00,  6.25000000e+00, -1.19047619e+00,  2.38095238e+01,
#         1.58730159e+03,  4.36507937e+04]), array([ 3.53000000e+00,  6.33333333e+00,  1.19047619e+00,  2.38095238e+01,
#        -1.36720265e-10, -1.05820106e+04, -3.19016495e+05])]
# Đa thức nội suy là:
# Bậc đa thức nội suy: 6
#
# -319016.49548714363 x^6
# 3170012.4494248084 x^5
# -13121508.714599399 x^4
# 28959518.946472865 x^3
# -35942419.343610786 x^2
# 23785255.515102446 x^1
# -6556663.838727261 x^0

# %% [markdown]
# ## 2. Tính giá trị đa thức tại một điểm bất kì

# %%
# Cần tính giá trị nội suy tại điểm x_
x_ = 2.8

print("Giá trị đa thức nội suy tại: x = {0}\nLà: {1}".format(x_, hoocnerChia(a, x_).pop()))
# Out:
# Giá trị đa thức nội suy tại: x = 2.8
# Là: -708709.9849483566
